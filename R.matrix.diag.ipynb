# %%
m<-matrix(4,3,3)

# %%
m
# Out:
#      [,1] [,2] [,3]
# [1,] 4    4    4
# [2,] 4    4    4
# [3,] 4    4    4

# %%
m<-diag(1,3,3)

# %%
m
# Out:
#      [,1] [,2] [,3]
# [1,] 1    0    0
# [2,] 0    1    0
# [3,] 0    0    1

# %%
m<-diag(5,3,3)
m
# Out:
#      [,1] [,2] [,3]
# [1,] 5    0    0
# [2,] 0    5    0
# [3,] 0    0    5

# %%
m<-diag(1:3)
m
# Out:
#      [,1] [,2] [,3]
# [1,] 1    0    0
# [2,] 0    2    0
# [3,] 0    0    3

# %%
m<-diag(1:5)
m
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    0    0    0    0
# [2,] 0    2    0    0    0
# [3,] 0    0    3    0    0
# [4,] 0    0    0    4    0
# [5,] 0    0    0    0    5

# %%
m<-matrix(4,3,3)
m
# Out:
#      [,1] [,2] [,3]
# [1,] 4    4    4
# [2,] 4    4    4
# [3,] 4    4    4

# %%
diag(m)
# Out:
# [1] 4 4 4
